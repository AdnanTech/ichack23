# %%
import random
mv = 0
mv2 = 0
for i in range(0, 1000):
  mv = min(mv, random.random()/ 2)
  mv2 = max(mv2, random.random() / 2 / 2)
print(mv, mv2)
# Out:
# 0 0.2499850536635349

# %%
import random

zones = [(0, 40), (41, 50), (51, 90), (91, 110), (111, 130), (131, 150)]
zone_3_l = [0, 40]
zone_21_l = [41, 50]
zone_0 = [51, 90]
zone_1_r = [91, 110]
zone_2_r = [111, 130]
zone_3_r = [131, 150]

val = 80

zone_default = 0.5

# %%
data = []
for i in range(0, 1000):
  if zones[0][0] <= val <= zones[0][1]:
    val += -1 if random.random() / 2 / 2< zone_default else 1
  elif zones[1][0] <= val <= zones[1][1]:
    val += -1 if random.random() / 2< zone_default else 1
  elif zones[2][0] <= val <= zones[2][1]:
    val += -1 if random.random() < zone_default else 1
  elif zones[3][0] <= val <= zones[3][1]:
    val += -1 if random.random() / 2< zone_default else 1
  elif zones[4][0] <= val <= zones[4][1]:
    val += -1 if random.random() / 2/ 2< zone_default else 1
  elif zones[5][0] <= val <= zones[5][1]:
    val += -1 if random.random() /2 /2/2< zone_default else 1
  
  data.append(val)

# %%
import matplotlib.pyplot as plt

# Plot the list of numbers
plt.plot(data)

# Show the plot
plt.show()
